# %% [markdown]
# <div class="pull-right"><img src=KEY-logo.png></div/>

# %% [markdown]
# ## Knowledge representation and similarity
# ### Grounding (Word-Sense Disambiguation) to WordNet

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2018
# Caroline Barrière
#
# ***

# %% [markdown]
# In this notebook, first, you will explore Wordnet, a lexical semantic network, in which knowledge is organized by interrelated synsets (groups of synonyms).  Second, you will attempt Word-Sense Disambiguation (WSD), using simple Lesk-like algorithm which compares BOWs (bag-of-words).
#
# This notebook uses the same package NLTK as we used in the last notebook. We will also reuse some knowledge from the previous notebook (tokenization, lemmatization, POS tagging), so make sure to do the NLP Pipeline notebook before this one.
#
# *As you now have more experience, this notebook requires that you write more code by yourself than the previous ones.*

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time. Look for (**TO DO**) for the tasks that you need to perform.
# Make sure you *sign* (type your name) the notebook at the end. Once you're done, submit your notebook.
#
# ***

# %%
# let's import nltk, and wordnet

import nltk
from nltk.corpus import wordnet

# %% [markdown]
# **1. Exploring Wordnet**
#
# Let's first explore a bit the wordnet interface within nltk.
# You can also look a the [WordNet interface description](http://www.nltk.org/howto/wordnet.html)

# %%
# a synset is a concept associated with a set of synonyms

paperSenses = wordnet.synsets('paper')
print(paperSenses)
# Out:
# [Synset('paper.n.01'), Synset('composition.n.08'), Synset('newspaper.n.01'), Synset('paper.n.04'), Synset('paper.n.05'), Synset('newspaper.n.02'), Synset('newspaper.n.03'), Synset('paper.v.01'), Synset('wallpaper.v.01')]

# %% [markdown]
# This shows that there are 9 senses of paper, 7 nouns and 2 verbs.  The word displayed is the most representative word for each sense.
#
# You can try other words.  I recommend that you also perform the same search [online](http://wordnetweb.princeton.edu/perl/webwn) to better understand the results.

# %% [markdown]
# Let's look at the basic information in each synset.

# %%
# We define a function to print the basic information

def printBasicSynsetInfo(d):
    print("SynLemmas")
    print(d.lemmas())
    print("Synonyms")
    synonyms = [l.name() for l in d.lemmas()]
    print(synonyms)
    print("Definition")
    print(d.definition())

# %%
# We can print the information for each sense of "paper"

for i in range(len(paperSenses)):
    print("[Sense " + str(i) + "]")
    printBasicSynsetInfo(paperSenses[i])
    print()
# Out:
# [Sense 0]
# SynLemmas
# [Lemma('paper.n.01.paper')]
# Synonyms
# ['paper']
# Definition
# a material made of cellulose pulp derived mainly from wood or rags or certain grasses
#
# [Sense 1]
# SynLemmas
# [Lemma('composition.n.08.composition'), Lemma('composition.n.08.paper'), Lemma('composition.n.08.report'), Lemma('composition.n.08.theme')]
# Synonyms
# ['composition', 'paper', 'report', 'theme']
# Definition
# an essay (especially one written as an assignment)
#
# [Sense 2]
# SynLemmas
# [Lemma('newspaper.n.01.newspaper'), Lemma('newspaper.n.01.paper')]
# Synonyms
# ['newspaper', 'paper']
# Definition
# a daily or weekly publication on folded sheets; contains news and articles and advertisements
#
# [Sense 3]
# SynLemmas
# [Lemma('paper.n.04.paper')]
# Synonyms
# ['paper']
# Definition
# a medium for written communication
#
# [Sense 4]
# SynLemmas
# [Lemma('paper.n.05.paper')]
# Synonyms
# ['paper']
# Definition
# a scholarly article describing the results of observations or stating hypotheses
#
# [Sense 5]
# SynLemmas
# [Lemma('newspaper.n.02.newspaper'), Lemma('newspaper.n.02.paper'), Lemma('newspaper.n.02.newspaper_publisher')]
# Synonyms
# ['newspaper', 'paper', 'newspaper_publisher']
# Definition
# a business firm that publishes newspapers
#
# [Sense 6]
# SynLemmas
# [Lemma('newspaper.n.03.newspaper'), Lemma('newspaper.n.03.paper')]
# Synonyms
# ['newspaper', 'paper']
# Definition
# the physical object that is the product of a newspaper publisher
#
# [Sense 7]
# SynLemmas
# [Lemma('paper.v.01.paper')]
# Synonyms
# ['paper']
# Definition
# cover with paper
#
# [Sense 8]
# SynLemmas
# [Lemma('wallpaper.v.01.wallpaper'), Lemma('wallpaper.v.01.paper')]
# Synonyms
# ['wallpaper', 'paper']
# Definition
# cover with wallpaper

# %% [markdown]
# A rich taxonomy has been manually developed in Wordnet, making it a rich resource.

# %% [markdown]
# **(TO-DO : Q1)** Choose two words, and write code to print the taxonomic information for all senses of those words.

# %%
# We define a function to print the basic information, receives a synset

def printTaxonomyInfo(d):
    synonyms = [l.name() for l in d.lemmas()]
    print(synonyms)
    print("Hypernyms:")
    print(d.hypernyms())
    print("Hyponyms:")
    print(d.hyponyms())

# %%
# Q1 - ANSWER
# We can print the taxonomy information for each sense of a word X

for i in range(len(paperSenses)):
    print("[Taxonomy " + str(i) + "]")
    printTaxonomyInfo(paperSenses[i])
    print()
# Out:
# [Taxonomy 0]
# ['paper']
# Hypernyms:
# [Synset('material.n.01')]
# Hyponyms:
# [Synset('art_paper.n.01'), Synset('blotting_paper.n.01'), Synset('blueprint_paper.n.01'), Synset('carbon_paper.n.01'), Synset('card.n.01'), Synset('cardboard.n.01'), Synset('cartridge_paper.n.02'), Synset('chad.n.01'), Synset('computer_paper.n.01'), Synset('confetti.n.01'), Synset('construction_paper.n.01'), Synset('crepe.n.01'), Synset('drawing_paper.n.01'), Synset('filter_paper.n.01'), Synset('flypaper.n.01'), Synset('graph_paper.n.01'), Synset('greaseproof_paper.n.01'), Synset('india_paper.n.01'), Synset('linen.n.02'), Synset('litmus_paper.n.01'), Synset('manifold_paper.n.01'), Synset('manila.n.01'), Synset('music_paper.n.01'), Synset('newspaper.n.04'), Synset('oilpaper.n.01'), Synset('pad.n.01'), Synset('paper_tape.n.01'), Synset('paper_toweling.n.01'), Synset('papier-mache.n.01'), Synset('papyrus.n.01'), Synset('parchment.n.01'), Synset('rice_paper.n.01'), Synset('roofing_paper.n.01'), Synset('sheet.n.02'), Synset('ticker_tape.n.01'), Synset('tissue.n.02'), Synset('tracing_paper.n.01'), Synset('transfer_paper.n.01'), Synset('wallpaper.n.01'), Synset('waste_paper.n.01'), Synset('wax_paper.n.01'), Synset('wrapping_paper.n.01'), Synset('writing_paper.n.01')]
#
# [Taxonomy 1]
# ['composition', 'paper', 'report', 'theme']
# Hypernyms:
# [Synset('essay.n.01')]
# Hyponyms:
# [Synset('term_paper.n.01')]
#
# [Taxonomy 2]
# ['newspaper', 'paper']
# Hypernyms:
# [Synset('press.n.02')]
# Hyponyms:
# [Synset('daily.n.01'), Synset('gazette.n.01'), Synset('school_newspaper.n.01'), Synset('tabloid.n.02')]
#
# [Taxonomy 3]
# ['paper']
# Hypernyms:
# [Synset('medium.n.01')]
# Hyponyms:
# []
#
# [Taxonomy 4]
# ['paper']
# Hypernyms:
# [Synset('article.n.01')]
# Hyponyms:
# []
#
# [Taxonomy 5]
# ['newspaper', 'paper', 'newspaper_publisher']
# Hypernyms:
# [Synset('publisher.n.01')]
# Hyponyms:
# []
#
# [Taxonomy 6]
# ['newspaper', 'paper']
# Hypernyms:
# [Synset('product.n.02')]
# Hyponyms:
# []
#
# [Taxonomy 7]
# ['paper']
# Hypernyms:
# [Synset('cover.v.01')]
# Hyponyms:
# []
#
# [Taxonomy 8]
# ['wallpaper', 'paper']
# Hypernyms:
# [Synset('cover.v.01')]
# Hyponyms:
# []

# %% [markdown]
# **2. Word-Sense Disambiguation.**
#
# Let's now implement a simple modified Lesk algorithm for WSD.
# The idea is to compare the sentence containing the ambiguous word W to all the definitions of W and choose the most similar.

# %% [markdown]
# (Step 1) Create a BOW (bag of words) for each definition.

# %%
# we will need the tokenizer

from nltk import word_tokenize

# %%
# define a small method to return the set of words found in a text
# we can exclude some words

def bow(text, excluded = None):
    text = text.replace("_", " ") # the compound nouns in wordnet text have _
    tokens = word_tokenize(text)
    setTokens = set(tokens)
    if excluded != None:
        if (excluded in setTokens):
            setTokens.remove(excluded)
    return setTokens

# %%
# testing 
print(bow("There is a lot of food on the table", excluded='table'))
print(bow("He wrote an excellent conference paper referred by many researchers", excluded='paper'))
# Out:
# {'the', 'food', 'lot', 'There', 'on', 'of', 'a', 'is'}
# {'conference', 'He', 'referred', 'an', 'wrote', 'by', 'many', 'excellent', 'researchers'}

# %%
# make BOWs for all the senses in a received word
# exclude from the BOW, the word being defined

def makeDefBOWs(testWord):
    synsets = wordnet.synsets(testWord)
    defs = [s.definition() for s in synsets]
    bows = [bow(d, excluded=testWord) for d in defs]
    return bows

# %%
# try with different words, look at the resulting info

testWord = "cell" # bank, course, paper, ...
defBOWs = makeDefBOWs(testWord)
    
print(*defBOWs, sep="\n")  # to print a list on separate lines
# Out:
# {'compartment', 'any', 'small'}
# {';', 'the', 'may', 'units', 'tissues', 'they', 'plants', 'as', 'or', 'animals', 'life', 'in', 'basic', 'functional', '(', 'exist', 'organisms', 'biology', 'and', 'independent', 'monads', 'form', 'higher', 'of', 'all', 'structural', ')', 'unit', 'colonies'}
# {'result', 'that', 'as', 'reaction', 'an', 'electric', 'the', 'device', 'delivers', 'chemical', 'of', 'a', 'current'}
# {'as', 'or', 'larger', 'the', 'political', 'small', 'serving', 'part', 'nucleus', 'unit', 'of', 'movement', 'a'}
# {'an', 'short-range', 'sections', 'hand-held', 'a', 'mobile', 'in', 'transmitter/receiver', 'with', ',', 'its', 'each', 'small', 'divided', 'radiotelephone', 'use', 'for', 'own', 'into', 'area'}
# {'room', 'or', 'nun', 'which', 'in', 'small', 'lives', 'monk', 'a'}
# {'where', 'room', 'prisoner', 'kept', 'a', 'is'}

# %% [markdown]
# (Step 2) Create a method to compare BOWs

# %%
# We're interested in the size of the intersection between the BOWs
# If you wish to see the words in common to understand the results, uncomment the prints

def bowOverlap(bow1, bow2):
    #print(bow1)
    #print(bow2)
    #print(bow1.intersection(bow2))
    #print(len(bow1.intersection(bow2)))
    return len(bow1.intersection(bow2))

# %% [markdown]
# **(TO-DO: Q2)** Implement the (Step 3) of the algorithm.  The (Step 3) consist in comparing the BOW of a test sentence (let's call it our context C) containing an ambiguous word (X) to the BOWs of all the senses of the X.  To do Step 3, you need to complete the method below which receives a word X, as well as the text C in which X occurs.  The method should return the synsets with largest common BOWs with X.  Notice that there could be more than one maximum, so your method should return all synsets with maximum intersection.

# %%
# Q2 - ANSWER

# method receives a word and its context
# returns all the synsets with maximum overlap

def findMostProbableSense(word, context):
    bows = makeDefBOWs(word)
    textBOW = bow(context)
    # find senses with max overlap
    maxBagsSyns=[]
    maxOver = 0
    for bag in bows:
        overlap = bowOverlap(textBOW, bag)
        if(overlap>maxOver):
            maxBagSyns=[]
            for word in textBOW.intersection(bag):
                maxBagSyns.append(wordnet.synsets(word))
            maxOver = overlap
        elif(overlap==maxOver):
            for word in textBOW.intersection(bag):
                maxBagSyns.append(wordnet.synsets(word))
    #print(maxBagSyns)
    return maxBagSyns

# %% [markdown]
# ##### Your method should return the chosen senses for the example below.  We will test your method using the following code.

# %%
# Show the BOWs of the senses with the overlap, and the chosen sense(s)
# You can try with various words and sentences

testWord = "cell"
testSentence = "He lived in this prison cell for many years."


####  CALL TO YOUR METHOD RECEIVING THE WORD AND ITS CONTEXT
chosenSynsets = findMostProbableSense(testWord, testSentence)  

# print all the definitions of the most probable senses
for s in chosenSynsets:
    for t in s:
        printBasicSynsetInfo(t)
# Out:
# SynLemmas
# [Lemma('inch.n.01.inch'), Lemma('inch.n.01.in')]
# Synonyms
# ['inch', 'in']
# Definition
# a unit of length equal to one twelfth of a foot
# SynLemmas
# [Lemma('indium.n.01.indium'), Lemma('indium.n.01.In'), Lemma('indium.n.01.atomic_number_49')]
# Synonyms
# ['indium', 'In', 'atomic_number_49']
# Definition
# a rare soft silvery metallic element; occurs in small quantities in sphalerite
# SynLemmas
# [Lemma('indiana.n.01.Indiana'), Lemma('indiana.n.01.Hoosier_State'), Lemma('indiana.n.01.IN')]
# Synonyms
# ['Indiana', 'Hoosier_State', 'IN']
# Definition
# a state in midwestern United States
# SynLemmas
# [Lemma('in.s.01.in')]
# Synonyms
# ['in']
# Definition
# holding office
# SynLemmas
# [Lemma('in.s.02.in')]
# Synonyms
# ['in']
# Definition
# directed or bound inward
# SynLemmas
# [Lemma('in.s.03.in')]
# Synonyms
# ['in']
# Definition
# currently fashionable
# SynLemmas
# [Lemma('in.r.01.in'), Lemma('in.r.01.inwards'), Lemma('in.r.01.inward')]
# Synonyms
# ['in', 'inwards', 'inward']
# Definition
# to or toward the inside of

# %% [markdown]
# **(TO-DO: Q3)** What do you notice? With the example above for "cell", what are the words making the BOWs look similar?  Are these significant words?

# %% [markdown]
# *Q3-ANSWER*
#
# The words that are in common 'in' and 'for'
# These are fairly significant words because it determines that 'cell' is not an object but a place.  If it were interpreted as an object these words would likely nbot be used

# %% [markdown]
# **(TO-DO: Q4)  Refining our BOWs**
#
# **Exploring variations:**
# 1. What if you lowercase everything?
# 2. What if you apply lemmatisation on all words in the BOWs?
# 3. What if you focus on only the NOUNS in the BOWs?
#
# (hint) Go back to your notebook NLP pipeline for questions (2) use the lemmatizer and (3) perform POS tagging on the sentences.
#
# For your answer (code to write):
#
# a) First complete the BOW method below in which I've added parameters to possibly activate the lowercase, the lemmatization and the POS tagging.
# b) Add a few tests to see if your BOW works.

# %%
# Q4 - ANSWER - part a)

# The parameters possibly ACTIVATE lowercase, lemmatization, and keeping only Nouns in BOWs.

# nltk contains a method to obtain the part-of-speech of each token
# Download the wordnet resource
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
wnl = nltk.WordNetLemmatizer()

def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.ADV  # just use as default, for ADV the lemmatizer doesn't change anything 

# refine the method with parameters
def bow(text, excluded = None, lowercase = False, lemmatize=False, nounsOnly=False):
    text = text.replace("_", " ") # the compound nouns in wordnet text have _
    tokens = word_tokenize(text)
    setTokens = set(tokens)
    if excluded != None:
        if (excluded in setTokens):
            setTokens.remove(excluded)
    
    if lowercase:
        for token in setTokens:
            token=token.lower()
            
    if lemmatize:
        setTokens = [wnl.lemmatize(t) for t in tokens]
    
    if nounsOnly:
        
        posTokens = nltk.pos_tag(setTokens)
        wordnet_tags = [get_wordnet_pos(p[1]) for p in posTokens]
        #print(wordnet_tags)
        #print(posTokens)
        for p in posTokens:
        
            wordnetPos = get_wordnet_pos(p[1])
            #print(wordnetPos)
            if (wordnetPos!='n'):
                #print(setTokens)
                setTokens.remove(p[0])
      
            
        
    return setTokens
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/reynadoerwald/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Q4 - ANSWER - part b)

# TEST YOUR METHOD 
print(bow("There is a lot of food on the table", excluded='table', lowercase=True, lemmatize=True, nounsOnly=True))
# Your example 1
print(bow("This is the final notebook for CSI4106", excluded='notebook', lowercase=False, lemmatize=True, nounsOnly=False))
# Your example 2
print(bow("I really want Swiss Chalet right now", excluded='right', lowercase=True, lemmatize=False, nounsOnly=True))
# Out:
# ['lot', 'food', 'table']
# ['This', 'is', 'the', 'final', 'notebook', 'for', 'CSI4106']
# {'want', 'Chalet'}

# %% [markdown]
# **(TO-DO: Q5)** TESTING BOW VARIATIONS IN LESK-LIKE DISAMBIGUATION
#
# a) Redo the method makeDefBOW and findMostProbableSense to use the new parameters.
#
# b) Generate three example cases and test your disambiguation strategy programmed above.  An example case contains an ambiguous word (e.g. bank) and a sentence in which that word must be disambiguated (e.g. He sat on the bank throwing rocks in the water.).
#
# c) For your examples, which filtering seems to work better (with/without lemmatization, with/without focus only on nouns)?

# %%
# Q5 - ANSWER - part a)

# add the parameters to makeBOW as well, same default
def makeDefBOWs(testWord, lowercase=False, lemmatize=False, nounsOnly=False):
    synsets = wordnet.synsets(testWord)
    defs = [s.definition() for s in synsets]
    bows = [bow(d, excluded=testWord, lowercase=lowercase, lemmatize=lemmatize, nounsOnly=nounsOnly) for d in defs]
    return bows


# also add the parameter here, copy your method from above and add a parameter for stemming
# def findMostProbableSense(senses, text, stemming=False):
def findMostProbableSense(word, text, lowercase=False, lemmatize=False, nounsOnly=False):
    bows = makeDefBOWs(word, lowercase=lowercase, lemmatize=lemmatize, nounsOnly=nounsOnly)
    textBOW = bow(text)
    # find senses with max overlap
    maxBagSyns=[]
    maxOver = 0
    for bag in bows:
        overlap = bowOverlap(textBOW, bag)
        if(overlap>maxOver):
            maxBagSyns=[]
            for word in textBOW.intersection(bag):
                maxBagSyns.append(wordnet.synsets(word))
                maxOver = overlap
        elif(overlap==maxOver):
            for word in textBOW.intersection(bag):
                maxBagSyns.append(wordnet.synsets(word))
    #print(maxBagSyns)
    return maxBagSyns

# %%
# Q5 - ANSWER - part b)

testWord = "table"
testSentence = "There is a lot of food on the table."
chosenSynsets = findMostProbableSense(testWord, testSentence, lowercase=True, lemmatize=True, nounsOnly=True)  

# print all the definitions of the most probable senses
for s in chosenSynsets:
    for t in s:
        printBasicSynsetInfo(t)

    
# Your example 1
#
print("#################")
print("#   Example 1.  #")
print("#################")
testWord1 = "break"
testSentence1 = "I really need a break from school."
chosenSynsets1 = findMostProbableSense(testWord1, testSentence1, lowercase=True, lemmatize=False, nounsOnly=False)  
for s in chosenSynsets1:
    for t in s:
        printBasicSynsetInfo(t)


# Your example 2
#
print("#################")
print("#   Example 2.  #")
print("#################")
testWord2 = "clear"
testSentence2 = "Everything is so clear now."
chosenSynsets2 = findMostProbableSense(testWord2, testSentence2, lowercase=False, lemmatize=True, nounsOnly=False)  
for s in chosenSynsets2:
    for t in s:
        printBasicSynsetInfo(t)



# Your example 3
#
print("#################")
print("#   Example 3.  #")
print("#################")

testWord3 = "light"
testSentence3 = "Justyn can see light in the Chalet."
chosenSynsets3 = findMostProbableSense(testWord3, testSentence3, lowercase=True, lemmatize=True, nounsOnly=False)  

for s in chosenSynsets3:
    for t in s:
        printBasicSynsetInfo(t)
# Out:
# SynLemmas
# [Lemma('table.n.01.table'), Lemma('table.n.01.tabular_array')]
# Synonyms
# ['table', 'tabular_array']
# Definition
# a set of data arranged in rows and columns
# SynLemmas
# [Lemma('table.n.02.table')]
# Synonyms
# ['table']
# Definition
# a piece of furniture having a smooth flat top that is usually supported by one or more vertical legs
# SynLemmas
# [Lemma('table.n.03.table')]
# Synonyms
# ['table']
# Definition
# a piece of furniture with tableware for a meal laid out on it
# SynLemmas
# [Lemma('mesa.n.01.mesa'), Lemma('mesa.n.01.table')]
# Synonyms
# ['mesa', 'table']
# Definition
# flat tableland with steep edges
# SynLemmas
# [Lemma('table.n.05.table')]
# Synonyms
# ['table']
# Definition
# a company of people assembled at a table for a meal or game
# SynLemmas
# [Lemma('board.n.04.board'), Lemma('board.n.04.table')]
# Synonyms
# ['board', 'table']
# Definition
# food or meals in general
# SynLemmas
# [Lemma('postpone.v.01.postpone'), Lemma('postpone.v.01.prorogue'), Lemma('postpone.v.01.hold_over'), Lemma('postpone.v.01.put_over'), Lemma('postpone.v.01.table'), Lemma('postpone.v.01.shelve'), Lemma('postpone.v.01.set_back'), Lemma('postpone.v.01.defer'), Lemma('postpone.v.01.remit'), Lemma('postpone.v.01.put_off')]
# Synonyms
# ['postpone', 'prorogue', 'hold_over', 'put_over', 'table', 'shelve', 'set_back', 'defer', 'remit', 'put_off']
# Definition
# hold back to a later time
# SynLemmas
# [Lemma('table.v.02.table'), Lemma('table.v.02.tabularize'), Lemma('table.v.02.tabularise'), Lemma('table.v.02.tabulate')]
# Synonyms
# ['table', 'tabularize', 'tabularise', 'tabulate']
# Definition
# arrange or enter in tabular form
# SynLemmas
# [Lemma('food.n.01.food'), Lemma('food.n.01.nutrient')]
# Synonyms
# ['food', 'nutrient']
# Definition
# any substance that can be metabolized by an animal to give energy and build tissue
# SynLemmas
# [Lemma('food.n.02.food'), Lemma('food.n.02.solid_food')]
# Synonyms
# ['food', 'solid_food']
# Definition
# any solid substance (as opposed to liquid) that is used as a source of nourishment
# SynLemmas
# [Lemma('food.n.03.food'), Lemma('food.n.03.food_for_thought'), Lemma('food.n.03.intellectual_nourishment')]
# Synonyms
# ['food', 'food_for_thought', 'intellectual_nourishment']
# Definition
# anything that provides mental stimulus for thinking
# #################
# #   Example 1.  #
# #################
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# SynLemmas
# [Lemma('angstrom.n.01.angstrom'), Lemma('angstrom.n.01.angstrom_unit'), Lemma('angstrom.n.01.A')]
# Synonyms
# ['angstrom', 'angstrom_unit', 'A']
# Definition
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# SynLemmas
# [Lemma('vitamin_a.n.01.vitamin_A'), Lemma('vitamin_a.n.01.antiophthalmic_factor'), Lemma('vitamin_a.n.01.axerophthol'), Lemma('vitamin_a.n.01.A')]
# Synonyms
# ['vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A']
# Definition
# any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
# SynLemmas
# [Lemma('deoxyadenosine_monophosphate.n.01.deoxyadenosine_monophosphate'), Lemma('deoxyadenosine_monophosphate.n.01.A')]
# Synonyms
# ['deoxyadenosine_monophosphate', 'A']
# Definition
# one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# SynLemmas
# [Lemma('adenine.n.01.adenine'), Lemma('adenine.n.01.A')]
# Synonyms
# ['adenine', 'A']
# Definition
# (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
# SynLemmas
# [Lemma('ampere.n.02.ampere'), Lemma('ampere.n.02.amp'), Lemma('ampere.n.02.A')]
# Synonyms
# ['ampere', 'amp', 'A']
# Definition
# the basic unit of electric current adopted under the Systeme International d'Unites
# SynLemmas
# [Lemma('a.n.06.A'), Lemma('a.n.06.a')]
# Synonyms
# ['A', 'a']
# Definition
# the 1st letter of the Roman alphabet
# SynLemmas
# [Lemma('a.n.07.A'), Lemma('a.n.07.type_A'), Lemma('a.n.07.group_A')]
# Synonyms
# ['A', 'type_A', 'group_A']
# Definition
# the blood group whose red cells carry the A antigen
# #################
# #   Example 2.  #
# #################
# SynLemmas
# [Lemma('clear.n.01.clear')]
# Synonyms
# ['clear']
# Definition
# the state of being free of suspicion
# SynLemmas
# [Lemma('open.n.01.open'), Lemma('open.n.01.clear')]
# Synonyms
# ['open', 'clear']
# Definition
# a clear or unobstructed space or expanse of land or water
# SynLemmas
# [Lemma('unclutter.v.01.unclutter'), Lemma('unclutter.v.01.clear')]
# Synonyms
# ['unclutter', 'clear']
# Definition
# rid of obstructions
# SynLemmas
# [Lemma('clear.v.02.clear')]
# Synonyms
# ['clear']
# Definition
# make a way or path by removing objects
# SynLemmas
# [Lemma('clear_up.v.04.clear_up'), Lemma('clear_up.v.04.clear'), Lemma('clear_up.v.04.light_up'), Lemma('clear_up.v.04.brighten')]
# Synonyms
# ['clear_up', 'clear', 'light_up', 'brighten']
# Definition
# become clear
# SynLemmas
# [Lemma('authorize.v.01.authorize'), Lemma('authorize.v.01.authorise'), Lemma('authorize.v.01.pass'), Lemma('authorize.v.01.clear')]
# Synonyms
# ['authorize', 'authorise', 'pass', 'clear']
# Definition
# grant authorization or clearance for
# SynLemmas
# [Lemma('clear.v.05.clear')]
# Synonyms
# ['clear']
# Definition
# remove
# SynLemmas
# [Lemma('pass.v.09.pass'), Lemma('pass.v.09.clear')]
# Synonyms
# ['pass', 'clear']
# Definition
# go unchallenged; be approved
# SynLemmas
# [Lemma('clear.v.07.clear')]
# Synonyms
# ['clear']
# Definition
# be debited and credited to the proper bank accounts
# SynLemmas
# [Lemma('clear.v.08.clear')]
# Synonyms
# ['clear']
# Definition
# go away or disappear
# SynLemmas
# [Lemma('clear.v.09.clear'), Lemma('clear.v.09.top')]
# Synonyms
# ['clear', 'top']
# Definition
# pass by, over, or under without making contact
# SynLemmas
# [Lemma('clear.v.10.clear'), Lemma('clear.v.10.clear_up'), Lemma('clear.v.10.shed_light_on'), Lemma('clear.v.10.crystallize'), Lemma('clear.v.10.crystallise'), Lemma('clear.v.10.crystalize'), Lemma('clear.v.10.crystalise'), Lemma('clear.v.10.straighten_out'), Lemma('clear.v.10.sort_out'), Lemma('clear.v.10.enlighten'), Lemma('clear.v.10.illuminate'), Lemma('clear.v.10.elucidate')]
# Synonyms
# ['clear', 'clear_up', 'shed_light_on', 'crystallize', 'crystallise', 'crystalize', 'crystalise', 'straighten_out', 'sort_out', 'enlighten', 'illuminate', 'elucidate']
# Definition
# make free from confusion or ambiguity; make clear
# SynLemmas
# [Lemma('clear.v.11.clear')]
# Synonyms
# ['clear']
# Definition
# free from payment of customs duties, as of a shipment
# SynLemmas
# [Lemma('clear.v.12.clear')]
# Synonyms
# ['clear']
# Definition
# clear from impurities, blemishes, pollution, etc.
# SynLemmas
# [Lemma('net.v.02.net'), Lemma('net.v.02.clear')]
# Synonyms
# ['net', 'clear']
# Definition
# yield as a net profit
# SynLemmas
# [Lemma('net.v.01.net'), Lemma('net.v.01.sack'), Lemma('net.v.01.sack_up'), Lemma('net.v.01.clear')]
# Synonyms
# ['net', 'sack', 'sack_up', 'clear']
# Definition
# make as a net profit
# SynLemmas
# [Lemma('gain.v.08.gain'), Lemma('gain.v.08.take_in'), Lemma('gain.v.08.clear'), Lemma('gain.v.08.make'), Lemma('gain.v.08.earn'), Lemma('gain.v.08.realize'), Lemma('gain.v.08.realise'), Lemma('gain.v.08.pull_in'), Lemma('gain.v.08.bring_in')]
# Synonyms
# ['gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in']
# Definition
# earn on some commercial or business transaction; earn as salary or wages
# SynLemmas
# [Lemma('clear.v.16.clear')]
# Synonyms
# ['clear']
# Definition
# sell
# SynLemmas
# [Lemma('clear.v.17.clear')]
# Synonyms
# ['clear']
# Definition
# pass an inspection or receive authorization
# SynLemmas
# [Lemma('acquit.v.01.acquit'), Lemma('acquit.v.01.assoil'), Lemma('acquit.v.01.clear'), Lemma('acquit.v.01.discharge'), Lemma('acquit.v.01.exonerate'), Lemma('acquit.v.01.exculpate')]
# Synonyms
# ['acquit', 'assoil', 'clear', 'discharge', 'exonerate', 'exculpate']
# Definition
# pronounce not guilty of criminal charges
# SynLemmas
# [Lemma('clear.v.19.clear'), Lemma('clear.v.19.solve')]
# Synonyms
# ['clear', 'solve']
# Definition
# settle, as of a debt
# SynLemmas
# [Lemma('clear.v.20.clear')]
# Synonyms
# ['clear']
# Definition
# make clear, bright, light, or translucent
# SynLemmas
# [Lemma('clear.v.21.clear')]
# Synonyms
# ['clear']
# Definition
# rid of instructions or data
# SynLemmas
# [Lemma('clear.v.22.clear')]
# Synonyms
# ['clear']
# Definition
# remove (people) from a building
# SynLemmas
# [Lemma('clear.v.23.clear')]
# Synonyms
# ['clear']
# Definition
# remove the occupants of
# SynLemmas
# [Lemma('clear.v.24.clear'), Lemma('clear.v.24.clear_up')]
# Synonyms
# ['clear', 'clear_up']
# Definition
# free (the throat) by making a rasping sound
# SynLemmas
# [Lemma('clear.a.01.clear')]
# Synonyms
# ['clear']
# Definition
# readily apparent to the mind
# SynLemmas
# [Lemma('clear.s.02.clear')]
# Synonyms
# ['clear']
# Definition
# free from confusion or doubt
# SynLemmas
# [Lemma('clear.s.03.clear'), Lemma('clear.s.03.open')]
# Synonyms
# ['clear', 'open']
# Definition
# affording free passage or view
# SynLemmas
# [Lemma('clear.a.04.clear')]
# Synonyms
# ['clear']
# Definition
# allowing light to pass through
# SynLemmas
# [Lemma('clear.s.05.clear')]
# Synonyms
# ['clear']
# Definition
# free from contact or proximity or connection
# SynLemmas
# [Lemma('clear.s.06.clear')]
# Synonyms
# ['clear']
# Definition
# characterized by freedom from troubling thoughts (especially guilt)
# SynLemmas
# [Lemma('clean.s.03.clean'), Lemma('clean.s.03.clear'), Lemma('clean.s.03.light'), Lemma('clean.s.03.unclouded')]
# Synonyms
# ['clean', 'clear', 'light', 'unclouded']
# Definition
# (of sound or color) free from anything that dulls or dims
# SynLemmas
# [Lemma('clear.s.08.clear'), Lemma('clear.s.08.unmortgaged')]
# Synonyms
# ['clear', 'unmortgaged']
# Definition
# (especially of a title) free from any encumbrance or limitation that presents a question of fact or law
# SynLemmas
# [Lemma('clear.s.09.clear'), Lemma('clear.s.09.clean-cut'), Lemma('clear.s.09.clear-cut')]
# Synonyms
# ['clear', 'clean-cut', 'clear-cut']
# Definition
# clear and distinct to the senses; easily perceptible
# SynLemmas
# [Lemma('well-defined.a.02.well-defined'), Lemma('well-defined.a.02.clear')]
# Synonyms
# ['well-defined', 'clear']
# Definition
# accurately stated or described
# SynLemmas
# [Lemma('clear.a.11.clear')]
# Synonyms
# ['clear']
# Definition
# free from clouds or mist or haze
# SynLemmas
# [Lemma('clean.s.02.clean'), Lemma('clean.s.02.clear')]
# Synonyms
# ['clean', 'clear']
# Definition
# free of restrictions or qualifications
# SynLemmas
# [Lemma('clear.s.13.clear')]
# Synonyms
# ['clear']
# Definition
# free from flaw or blemish or impurity
# SynLemmas
# [Lemma('clear.s.14.clear')]
# Synonyms
# ['clear']
# Definition
# clear of charges or deductions
# SynLemmas
# [Lemma('clear.s.15.clear'), Lemma('clear.s.15.decipherable'), Lemma('clear.s.15.readable')]
# Synonyms
# ['clear', 'decipherable', 'readable']
# Definition
# easily deciphered
# SynLemmas
# [Lemma('absolved.s.01.absolved'), Lemma('absolved.s.01.clear'), Lemma('absolved.s.01.cleared'), Lemma('absolved.s.01.exculpated'), Lemma('absolved.s.01.exonerated'), Lemma('absolved.s.01.vindicated')]
# Synonyms
# ['absolved', 'clear', 'cleared', 'exculpated', 'exonerated', 'vindicated']
# Definition
# freed from any question of guilt
# SynLemmas
# [Lemma('clear.s.17.clear'), Lemma('clear.s.17.percipient')]
# Synonyms
# ['clear', 'percipient']
# Definition
# characterized by ease and quickness in perceiving
# SynLemmas
# [Lemma('clear.r.01.clear'), Lemma('clear.r.01.all_the_way')]
# Synonyms
# ['clear', 'all_the_way']
# Definition
# completely
# SynLemmas
# [Lemma('clearly.r.04.clearly'), Lemma('clearly.r.04.clear')]
# Synonyms
# ['clearly', 'clear']
# Definition
# in an easily perceptible manner
# #################
# #   Example 3.  #
# #################
# SynLemmas
# [Lemma('light.n.01.light'), Lemma('light.n.01.visible_light'), Lemma('light.n.01.visible_radiation')]
# Synonyms
# ['light', 'visible_light', 'visible_radiation']
# Definition
# (physics) electromagnetic radiation that can produce a visual sensation
# SynLemmas
# [Lemma('light.n.02.light'), Lemma('light.n.02.light_source')]
# Synonyms
# ['light', 'light_source']
# Definition
# any device serving as a source of illumination
# SynLemmas
# [Lemma('light.n.03.light')]
# Synonyms
# ['light']
# Definition
# a particular perspective or aspect of a situation
# SynLemmas
# [Lemma('luminosity.n.01.luminosity'), Lemma('luminosity.n.01.brightness'), Lemma('luminosity.n.01.brightness_level'), Lemma('luminosity.n.01.luminance'), Lemma('luminosity.n.01.luminousness'), Lemma('luminosity.n.01.light')]
# Synonyms
# ['luminosity', 'brightness', 'brightness_level', 'luminance', 'luminousness', 'light']
# Definition
# the quality of being luminous; emitting or reflecting light
# SynLemmas
# [Lemma('light.n.05.light')]
# Synonyms
# ['light']
# Definition
# an illuminated area
# SynLemmas
# [Lemma('light.n.06.light'), Lemma('light.n.06.illumination')]
# Synonyms
# ['light', 'illumination']
# Definition
# a condition of spiritual awareness; divine illumination
# SynLemmas
# [Lemma('light.n.07.light'), Lemma('light.n.07.lightness')]
# Synonyms
# ['light', 'lightness']
# Definition
# the visual effect of illumination on objects or scenes as created in pictures
# SynLemmas
# [Lemma('light.n.08.light')]
# Synonyms
# ['light']
# Definition
# a person regarded very fondly
# SynLemmas
# [Lemma('light.n.09.light'), Lemma('light.n.09.lighting')]
# Synonyms
# ['light', 'lighting']
# Definition
# having abundant light or illumination
# SynLemmas
# [Lemma('light.n.10.light')]
# Synonyms
# ['light']
# Definition
# mental understanding as an enlightening experience
# SynLemmas
# [Lemma('sparkle.n.01.sparkle'), Lemma('sparkle.n.01.twinkle'), Lemma('sparkle.n.01.spark'), Lemma('sparkle.n.01.light')]
# Synonyms
# ['sparkle', 'twinkle', 'spark', 'light']
# Definition
# merriment expressed by a brightness or gleam or animation of countenance
# SynLemmas
# [Lemma('light.n.12.light')]
# Synonyms
# ['light']
# Definition
# public awareness
# SynLemmas
# [Lemma('inner_light.n.01.Inner_Light'), Lemma('inner_light.n.01.Light'), Lemma('inner_light.n.01.Light_Within'), Lemma('inner_light.n.01.Christ_Within')]
# Synonyms
# ['Inner_Light', 'Light', 'Light_Within', 'Christ_Within']
# Definition
# a divine presence believed by Quakers to enlighten and guide the soul
# SynLemmas
# [Lemma('light.n.14.light')]
# Synonyms
# ['light']
# Definition
# a visual warning signal
# SynLemmas
# [Lemma('lighter.n.02.lighter'), Lemma('lighter.n.02.light'), Lemma('lighter.n.02.igniter'), Lemma('lighter.n.02.ignitor')]
# Synonyms
# ['lighter', 'light', 'igniter', 'ignitor']
# Definition
# a device for lighting or igniting fuel or charges or fires
# SynLemmas
# [Lemma('light.v.01.light'), Lemma('light.v.01.illume'), Lemma('light.v.01.illumine'), Lemma('light.v.01.light_up'), Lemma('light.v.01.illuminate')]
# Synonyms
# ['light', 'illume', 'illumine', 'light_up', 'illuminate']
# Definition
# make lighter or brighter
# SynLemmas
# [Lemma('light_up.v.05.light_up'), Lemma('light_up.v.05.fire_up'), Lemma('light_up.v.05.light')]
# Synonyms
# ['light_up', 'fire_up', 'light']
# Definition
# begin to smoke
# SynLemmas
# [Lemma('alight.v.01.alight'), Lemma('alight.v.01.light'), Lemma('alight.v.01.perch')]
# Synonyms
# ['alight', 'light', 'perch']
# Definition
# to come to rest, settle
# SynLemmas
# [Lemma('ignite.v.01.ignite'), Lemma('ignite.v.01.light')]
# Synonyms
# ['ignite', 'light']
# Definition
# cause to start burning; subject to fire or great heat
# SynLemmas
# [Lemma('fall.v.20.fall'), Lemma('fall.v.20.light')]
# Synonyms
# ['fall', 'light']
# Definition
# fall to somebody by assignment or lot
# SynLemmas
# [Lemma('unhorse.v.01.unhorse'), Lemma('unhorse.v.01.dismount'), Lemma('unhorse.v.01.light'), Lemma('unhorse.v.01.get_off'), Lemma('unhorse.v.01.get_down')]
# Synonyms
# ['unhorse', 'dismount', 'light', 'get_off', 'get_down']
# Definition
# alight from (a horse)
# SynLemmas
# [Lemma('light.a.01.light')]
# Synonyms
# ['light']
# Definition
# of comparatively little physical weight or density
# SynLemmas
# [Lemma('light.a.02.light'), Lemma('light.a.02.light-colored')]
# Synonyms
# ['light', 'light-colored']
# Definition
# (used of color) having a relatively small amount of coloring agent
# SynLemmas
# [Lemma('light.a.03.light')]
# Synonyms
# ['light']
# Definition
# of the military or industry; using (or being) relatively small or light arms or equipment
# SynLemmas
# [Lemma('light.a.04.light')]
# Synonyms
# ['light']
# Definition
# not great in degree or quantity or number
# SynLemmas
# [Lemma('light.a.05.light')]
# Synonyms
# ['light']
# Definition
# psychologically light; especially free from sadness or troubles
# SynLemmas
# [Lemma('light.a.06.light')]
# Synonyms
# ['light']
# Definition
# characterized by or emitting light
# SynLemmas
# [Lemma('unaccented.s.02.unaccented'), Lemma('unaccented.s.02.light'), Lemma('unaccented.s.02.weak')]
# Synonyms
# ['unaccented', 'light', 'weak']
# Definition
# (used of vowels or syllables) pronounced with little or no stress
# SynLemmas
# [Lemma('light.s.08.light')]
# Synonyms
# ['light']
# Definition
# easily assimilated in the alimentary canal; not rich or heavily seasoned
# SynLemmas
# [Lemma('light.s.09.light')]
# Synonyms
# ['light']
# Definition
# (used of soil) loose and large-grained in consistency
# SynLemmas
# [Lemma('clean.s.03.clean'), Lemma('clean.s.03.clear'), Lemma('clean.s.03.light'), Lemma('clean.s.03.unclouded')]
# Synonyms
# ['clean', 'clear', 'light', 'unclouded']
# Definition
# (of sound or color) free from anything that dulls or dims
# SynLemmas
# [Lemma('light.s.11.light'), Lemma('light.s.11.lightsome'), Lemma('light.s.11.tripping')]
# Synonyms
# ['light', 'lightsome', 'tripping']
# Definition
# moving easily and quickly; nimble
# SynLemmas
# [Lemma('light.s.12.light')]
# Synonyms
# ['light']
# Definition
# demanding little effort; not burdensome
# SynLemmas
# [Lemma('light.a.13.light')]
# Synonyms
# ['light']
# Definition
# of little intensity or power or force
# SynLemmas
# [Lemma('light.a.14.light')]
# Synonyms
# ['light']
# Definition
# (physics, chemistry) not having atomic weight greater than average
# SynLemmas
# [Lemma('faint.s.04.faint'), Lemma('faint.s.04.light'), Lemma('faint.s.04.swooning'), Lemma('faint.s.04.light-headed'), Lemma('faint.s.04.lightheaded')]
# Synonyms
# ['faint', 'light', 'swooning', 'light-headed', 'lightheaded']
# Definition
# weak and likely to lose consciousness
# SynLemmas
# [Lemma('light.s.16.light')]
# Synonyms
# ['light']
# Definition
# very thin and insubstantial
# SynLemmas
# [Lemma('abstemious.s.02.abstemious'), Lemma('abstemious.s.02.light')]
# Synonyms
# ['abstemious', 'light']
# Definition
# marked by temperance in indulgence
# SynLemmas
# [Lemma('light.s.18.light'), Lemma('light.s.18.scant'), Lemma('light.s.18.short')]
# Synonyms
# ['light', 'scant', 'short']
# Definition
# less than the correct or legal or full amount often deliberately so
# SynLemmas
# [Lemma('light.s.19.light')]
# Synonyms
# ['light']
# Definition
# having little importance
# SynLemmas
# [Lemma('light.s.20.light')]
# Synonyms
# ['light']
# Definition
# intended primarily as entertainment; not serious or profound
# SynLemmas
# [Lemma('idle.s.04.idle'), Lemma('idle.s.04.light')]
# Synonyms
# ['idle', 'light']
# Definition
# silly or trivial
# SynLemmas
# [Lemma('light.s.22.light')]
# Synonyms
# ['light']
# Definition
# designed for ease of movement or to carry little weight
# SynLemmas
# [Lemma('light.s.23.light'), Lemma('light.s.23.lite'), Lemma('light.s.23.low-cal'), Lemma('light.s.23.calorie-free')]
# Synonyms
# ['light', 'lite', 'low-cal', 'calorie-free']
# Definition
# having relatively few calories
# SynLemmas
# [Lemma('light.s.24.light'), Lemma('light.s.24.wakeful')]
# Synonyms
# ['light', 'wakeful']
# Definition
# (of sleep) easily disturbed
# SynLemmas
# [Lemma('easy.s.10.easy'), Lemma('easy.s.10.light'), Lemma('easy.s.10.loose'), Lemma('easy.s.10.promiscuous'), Lemma('easy.s.10.sluttish'), Lemma('easy.s.10.wanton')]
# Synonyms
# ['easy', 'light', 'loose', 'promiscuous', 'sluttish', 'wanton']
# Definition
# casual and unrestrained in sexual behavior
# SynLemmas
# [Lemma('lightly.r.02.lightly'), Lemma('lightly.r.02.light')]
# Synonyms
# ['lightly', 'light']
# Definition
# with few burdens
# SynLemmas
# [Lemma('inch.n.01.inch'), Lemma('inch.n.01.in')]
# Synonyms
# ['inch', 'in']
# Definition
# a unit of length equal to one twelfth of a foot
# SynLemmas
# [Lemma('indium.n.01.indium'), Lemma('indium.n.01.In'), Lemma('indium.n.01.atomic_number_49')]
# Synonyms
# ['indium', 'In', 'atomic_number_49']
# Definition
# a rare soft silvery metallic element; occurs in small quantities in sphalerite
# SynLemmas
# [Lemma('indiana.n.01.Indiana'), Lemma('indiana.n.01.Hoosier_State'), Lemma('indiana.n.01.IN')]
# Synonyms
# ['Indiana', 'Hoosier_State', 'IN']
# Definition
# a state in midwestern United States
# SynLemmas
# [Lemma('in.s.01.in')]
# Synonyms
# ['in']
# Definition
# holding office
# SynLemmas
# [Lemma('in.s.02.in')]
# Synonyms
# ['in']
# Definition
# directed or bound inward
# SynLemmas
# [Lemma('in.s.03.in')]
# Synonyms
# ['in']
# Definition
# currently fashionable
# SynLemmas
# [Lemma('in.r.01.in'), Lemma('in.r.01.inwards'), Lemma('in.r.01.inward')]
# Synonyms
# ['in', 'inwards', 'inward']
# Definition
# to or toward the inside of
# SynLemmas
# [Lemma('light.n.01.light'), Lemma('light.n.01.visible_light'), Lemma('light.n.01.visible_radiation')]
# Synonyms
# ['light', 'visible_light', 'visible_radiation']
# Definition
# (physics) electromagnetic radiation that can produce a visual sensation
# SynLemmas
# [Lemma('light.n.02.light'), Lemma('light.n.02.light_source')]
# Synonyms
# ['light', 'light_source']
# Definition
# any device serving as a source of illumination
# SynLemmas
# [Lemma('light.n.03.light')]
# Synonyms
# ['light']
# Definition
# a particular perspective or aspect of a situation
# SynLemmas
# [Lemma('luminosity.n.01.luminosity'), Lemma('luminosity.n.01.brightness'), Lemma('luminosity.n.01.brightness_level'), Lemma('luminosity.n.01.luminance'), Lemma('luminosity.n.01.luminousness'), Lemma('luminosity.n.01.light')]
# Synonyms
# ['luminosity', 'brightness', 'brightness_level', 'luminance', 'luminousness', 'light']
# Definition
# the quality of being luminous; emitting or reflecting light
# SynLemmas
# [Lemma('light.n.05.light')]
# Synonyms
# ['light']
# Definition
# an illuminated area
# SynLemmas
# [Lemma('light.n.06.light'), Lemma('light.n.06.illumination')]
# Synonyms
# ['light', 'illumination']
# Definition
# a condition of spiritual awareness; divine illumination
# SynLemmas
# [Lemma('light.n.07.light'), Lemma('light.n.07.lightness')]
# Synonyms
# ['light', 'lightness']
# Definition
# the visual effect of illumination on objects or scenes as created in pictures
# SynLemmas
# [Lemma('light.n.08.light')]
# Synonyms
# ['light']
# Definition
# a person regarded very fondly
# SynLemmas
# [Lemma('light.n.09.light'), Lemma('light.n.09.lighting')]
# Synonyms
# ['light', 'lighting']
# Definition
# having abundant light or illumination
# SynLemmas
# [Lemma('light.n.10.light')]
# Synonyms
# ['light']
# Definition
# mental understanding as an enlightening experience
# SynLemmas
# [Lemma('sparkle.n.01.sparkle'), Lemma('sparkle.n.01.twinkle'), Lemma('sparkle.n.01.spark'), Lemma('sparkle.n.01.light')]
# Synonyms
# ['sparkle', 'twinkle', 'spark', 'light']
# Definition
# merriment expressed by a brightness or gleam or animation of countenance
# SynLemmas
# [Lemma('light.n.12.light')]
# Synonyms
# ['light']
# Definition
# public awareness
# SynLemmas
# [Lemma('inner_light.n.01.Inner_Light'), Lemma('inner_light.n.01.Light'), Lemma('inner_light.n.01.Light_Within'), Lemma('inner_light.n.01.Christ_Within')]
# Synonyms
# ['Inner_Light', 'Light', 'Light_Within', 'Christ_Within']
# Definition
# a divine presence believed by Quakers to enlighten and guide the soul
# SynLemmas
# [Lemma('light.n.14.light')]
# Synonyms
# ['light']
# Definition
# a visual warning signal
# SynLemmas
# [Lemma('lighter.n.02.lighter'), Lemma('lighter.n.02.light'), Lemma('lighter.n.02.igniter'), Lemma('lighter.n.02.ignitor')]
# Synonyms
# ['lighter', 'light', 'igniter', 'ignitor']
# Definition
# a device for lighting or igniting fuel or charges or fires
# SynLemmas
# [Lemma('light.v.01.light'), Lemma('light.v.01.illume'), Lemma('light.v.01.illumine'), Lemma('light.v.01.light_up'), Lemma('light.v.01.illuminate')]
# Synonyms
# ['light', 'illume', 'illumine', 'light_up', 'illuminate']
# Definition
# make lighter or brighter
# SynLemmas
# [Lemma('light_up.v.05.light_up'), Lemma('light_up.v.05.fire_up'), Lemma('light_up.v.05.light')]
# Synonyms
# ['light_up', 'fire_up', 'light']
# Definition
# begin to smoke
# SynLemmas
# [Lemma('alight.v.01.alight'), Lemma('alight.v.01.light'), Lemma('alight.v.01.perch')]
# Synonyms
# ['alight', 'light', 'perch']
# Definition
# to come to rest, settle
# SynLemmas
# [Lemma('ignite.v.01.ignite'), Lemma('ignite.v.01.light')]
# Synonyms
# ['ignite', 'light']
# Definition
# cause to start burning; subject to fire or great heat
# SynLemmas
# [Lemma('fall.v.20.fall'), Lemma('fall.v.20.light')]
# Synonyms
# ['fall', 'light']
# Definition
# fall to somebody by assignment or lot
# SynLemmas
# [Lemma('unhorse.v.01.unhorse'), Lemma('unhorse.v.01.dismount'), Lemma('unhorse.v.01.light'), Lemma('unhorse.v.01.get_off'), Lemma('unhorse.v.01.get_down')]
# Synonyms
# ['unhorse', 'dismount', 'light', 'get_off', 'get_down']
# Definition
# alight from (a horse)
# SynLemmas
# [Lemma('light.a.01.light')]
# Synonyms
# ['light']
# Definition
# of comparatively little physical weight or density
# SynLemmas
# [Lemma('light.a.02.light'), Lemma('light.a.02.light-colored')]
# Synonyms
# ['light', 'light-colored']
# Definition
# (used of color) having a relatively small amount of coloring agent
# SynLemmas
# [Lemma('light.a.03.light')]
# Synonyms
# ['light']
# Definition
# of the military or industry; using (or being) relatively small or light arms or equipment
# SynLemmas
# [Lemma('light.a.04.light')]
# Synonyms
# ['light']
# Definition
# not great in degree or quantity or number
# SynLemmas
# [Lemma('light.a.05.light')]
# Synonyms
# ['light']
# Definition
# psychologically light; especially free from sadness or troubles
# SynLemmas
# [Lemma('light.a.06.light')]
# Synonyms
# ['light']
# Definition
# characterized by or emitting light
# SynLemmas
# [Lemma('unaccented.s.02.unaccented'), Lemma('unaccented.s.02.light'), Lemma('unaccented.s.02.weak')]
# Synonyms
# ['unaccented', 'light', 'weak']
# Definition
# (used of vowels or syllables) pronounced with little or no stress
# SynLemmas
# [Lemma('light.s.08.light')]
# Synonyms
# ['light']
# Definition
# easily assimilated in the alimentary canal; not rich or heavily seasoned
# SynLemmas
# [Lemma('light.s.09.light')]
# Synonyms
# ['light']
# Definition
# (used of soil) loose and large-grained in consistency
# SynLemmas
# [Lemma('clean.s.03.clean'), Lemma('clean.s.03.clear'), Lemma('clean.s.03.light'), Lemma('clean.s.03.unclouded')]
# Synonyms
# ['clean', 'clear', 'light', 'unclouded']
# Definition
# (of sound or color) free from anything that dulls or dims
# SynLemmas
# [Lemma('light.s.11.light'), Lemma('light.s.11.lightsome'), Lemma('light.s.11.tripping')]
# Synonyms
# ['light', 'lightsome', 'tripping']
# Definition
# moving easily and quickly; nimble
# SynLemmas
# [Lemma('light.s.12.light')]
# Synonyms
# ['light']
# Definition
# demanding little effort; not burdensome
# SynLemmas
# [Lemma('light.a.13.light')]
# Synonyms
# ['light']
# Definition
# of little intensity or power or force
# SynLemmas
# [Lemma('light.a.14.light')]
# Synonyms
# ['light']
# Definition
# (physics, chemistry) not having atomic weight greater than average
# SynLemmas
# [Lemma('faint.s.04.faint'), Lemma('faint.s.04.light'), Lemma('faint.s.04.swooning'), Lemma('faint.s.04.light-headed'), Lemma('faint.s.04.lightheaded')]
# Synonyms
# ['faint', 'light', 'swooning', 'light-headed', 'lightheaded']
# Definition
# weak and likely to lose consciousness
# SynLemmas
# [Lemma('light.s.16.light')]
# Synonyms
# ['light']
# Definition
# very thin and insubstantial
# SynLemmas
# [Lemma('abstemious.s.02.abstemious'), Lemma('abstemious.s.02.light')]
# Synonyms
# ['abstemious', 'light']
# Definition
# marked by temperance in indulgence
# SynLemmas
# [Lemma('light.s.18.light'), Lemma('light.s.18.scant'), Lemma('light.s.18.short')]
# Synonyms
# ['light', 'scant', 'short']
# Definition
# less than the correct or legal or full amount often deliberately so
# SynLemmas
# [Lemma('light.s.19.light')]
# Synonyms
# ['light']
# Definition
# having little importance
# SynLemmas
# [Lemma('light.s.20.light')]
# Synonyms
# ['light']
# Definition
# intended primarily as entertainment; not serious or profound
# SynLemmas
# [Lemma('idle.s.04.idle'), Lemma('idle.s.04.light')]
# Synonyms
# ['idle', 'light']
# Definition
# silly or trivial
# SynLemmas
# [Lemma('light.s.22.light')]
# Synonyms
# ['light']
# Definition
# designed for ease of movement or to carry little weight
# SynLemmas
# [Lemma('light.s.23.light'), Lemma('light.s.23.lite'), Lemma('light.s.23.low-cal'), Lemma('light.s.23.calorie-free')]
# Synonyms
# ['light', 'lite', 'low-cal', 'calorie-free']
# Definition
# having relatively few calories
# SynLemmas
# [Lemma('light.s.24.light'), Lemma('light.s.24.wakeful')]
# Synonyms
# ['light', 'wakeful']
# Definition
# (of sleep) easily disturbed
# SynLemmas
# [Lemma('easy.s.10.easy'), Lemma('easy.s.10.light'), Lemma('easy.s.10.loose'), Lemma('easy.s.10.promiscuous'), Lemma('easy.s.10.sluttish'), Lemma('easy.s.10.wanton')]
# Synonyms
# ['easy', 'light', 'loose', 'promiscuous', 'sluttish', 'wanton']
# Definition
# casual and unrestrained in sexual behavior
# SynLemmas
# [Lemma('lightly.r.02.lightly'), Lemma('lightly.r.02.light')]
# Synonyms
# ['lightly', 'light']
# Definition
# with few burdens
# SynLemmas
# [Lemma('inch.n.01.inch'), Lemma('inch.n.01.in')]
# Synonyms
# ['inch', 'in']
# Definition
# a unit of length equal to one twelfth of a foot
# SynLemmas
# [Lemma('indium.n.01.indium'), Lemma('indium.n.01.In'), Lemma('indium.n.01.atomic_number_49')]
# Synonyms
# ['indium', 'In', 'atomic_number_49']
# Definition
# a rare soft silvery metallic element; occurs in small quantities in sphalerite
# SynLemmas
# [Lemma('indiana.n.01.Indiana'), Lemma('indiana.n.01.Hoosier_State'), Lemma('indiana.n.01.IN')]
# Synonyms
# ['Indiana', 'Hoosier_State', 'IN']
# Definition
# a state in midwestern United States
# SynLemmas
# [Lemma('in.s.01.in')]
# Synonyms
# ['in']
# Definition
# holding office
# SynLemmas
# [Lemma('in.s.02.in')]
# Synonyms
# ['in']
# Definition
# directed or bound inward
# SynLemmas
# [Lemma('in.s.03.in')]
# Synonyms
# ['in']
# Definition
# currently fashionable
# SynLemmas
# [Lemma('in.r.01.in'), Lemma('in.r.01.inwards'), Lemma('in.r.01.inward')]
# Synonyms
# ['in', 'inwards', 'inward']
# Definition
# to or toward the inside of

# %% [markdown]
# *Q5 - ANSWER - part c)*
# With lematization and without nouns only seems to work best in my scenarios.

# %% [markdown]
# #### Signature
#
# I, Reyna Doerwald, declare that the answers provided in this notebook are my own.
